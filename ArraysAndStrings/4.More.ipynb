# %% [markdown]
# ## Strings:
# #### Since strings are immutable, simple concatenation will result in O(n^2) time complexity. But there are better approaches to build strings with just O(n) time.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Subarrays/substrings, subsequences, and subsets:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
